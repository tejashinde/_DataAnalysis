# %%
# %matplotlib inline
import pandas
import numpy
import matplotlib.pyplot as pyplot

# %%
dataframe = pandas.read_csv('./tmp/all_stocks_5yr.csv' , parse_dates = ['date'])

# %%
dataframe.set_index('date')
# Out:
#              open     high      low  close    volume Name
# date
# 2013-02-08  15.07  15.1200  14.6300  14.75   8407500  AAL
# 2013-02-11  14.89  15.0100  14.2600  14.46   8882000  AAL
# 2013-02-12  14.45  14.5100  14.1000  14.27   8126000  AAL
# 2013-02-13  14.30  14.9400  14.2500  14.66  10259500  AAL
# 2013-02-14  14.94  14.9600  13.1600  13.99  31879900  AAL
# 2013-02-15  13.93  14.6100  13.9300  14.50  15628000  AAL
# 2013-02-19  14.33  14.5600  14.0800  14.26  11354400  AAL
# 2013-02-20  14.17  14.2600  13.1500  13.33  14725200  AAL
# 2013-02-21  13.62  13.9500  12.9000  13.37  11922100  AAL
# 2013-02-22  13.57  13.6000  13.2100  13.57   6071400  AAL
# 2013-02-25  13.60  13.7600  13.0000  13.02   7186400  AAL
# 2013-02-26  13.14  13.4200  12.7000  13.26   9419000  AAL
# 2013-02-27  13.28  13.6200  13.1800  13.41   7390500  AAL
# 2013-02-28  13.49  13.6300  13.3900  13.43   6143600  AAL
# 2013-03-01  13.37  13.9500  13.3200  13.61   7376800  AAL
# ...

# %%
dataframe_AAPL = dataframe[dataframe.Name == 'AAPL']
dataframe_ZTS = dataframe[dataframe.Name == 'ZTS']

# %%
df3 = pandas.merge(dataframe_AAPL , dataframe_ZTS , how = 'outer' , on = 'date').set_index('date')

# %%
df3.resample('4M').sum().plot()

# %%
dataframe
# Out:
#              date   open     high      low  close    volume Name
# 0      2013-02-08  15.07  15.1200  14.6300  14.75   8407500  AAL
# 1      2013-02-11  14.89  15.0100  14.2600  14.46   8882000  AAL
# 2      2013-02-12  14.45  14.5100  14.1000  14.27   8126000  AAL
# 3      2013-02-13  14.30  14.9400  14.2500  14.66  10259500  AAL
# 4      2013-02-14  14.94  14.9600  13.1600  13.99  31879900  AAL
# 5      2013-02-15  13.93  14.6100  13.9300  14.50  15628000  AAL
# 6      2013-02-19  14.33  14.5600  14.0800  14.26  11354400  AAL
# 7      2013-02-20  14.17  14.2600  13.1500  13.33  14725200  AAL
# 8      2013-02-21  13.62  13.9500  12.9000  13.37  11922100  AAL
# 9      2013-02-22  13.57  13.6000  13.2100  13.57   6071400  AAL
# 10     2013-02-25  13.60  13.7600  13.0000  13.02   7186400  AAL
# 11     2013-02-26  13.14  13.4200  12.7000  13.26   9419000  AAL
# 12     2013-02-27  13.28  13.6200  13.1800  13.41   7390500  AAL
# ...

# %%
dataframe[['high','low']].apply(lambda x : numpy.mean((x[0],x[1])) , axis = 1)
# Out:
# 0         14.87500
# 1         14.63500
# 2         14.30500
# 3         14.59500
# 4         14.06000
# 5         14.27000
# 6         14.32000
# 7         13.70500
# 8         13.42500
# 9         13.40500
# 10        13.38000
# 11        13.06000
# 12        13.40000
# 13        13.51000
# 14        13.63500
# 15        13.77000
# 16        13.88000
# 17        14.46500
# 18        14.71500
# 19        15.02000
# 20        14.93000
# 21        15.27500
# 22        15.84000
# 23        16.14500
# 24        16.21000
# 25        16.02000
# 26        16.63000
# 27        17.10000
# 28        17.15000
# 29        17.03000
#             ...
# 619010    72.22500
# 619011    72.47000
# 619012    72.37000
# 619013    72.40000
# 619014    72.02750
# 619015    71.76000
# 619016    72.58640
# 619017    73.24500
# 619018    73.79035
# 619019    74.97000
# 619020    74.04000
# 619021    74.20000
# 619022    75.23000
# 619023    75.80500
# 619024    76.21000
# 619025    76.25000
# ...

# %%
dataframe['Percent Change of Volume'] = dataframe.volume.pct_change()

# %%
AAPL_PC = dataframe[dataframe.Name == 'AAPL']['volume'].pct_change()[1:]
AAL_PC = dataframe[dataframe.Name == 'AAL']['volume'].pct_change()[1:]

# %%
# dataframe_MG = pandas.merge(AAPL_PC , AAL_PC , how = 'outer' , on = 'date').set_index('date')

# %%
dataframe_MG[['Percent Change of Volume_x' , 'Percent Change of Volume_y']].plot()

# %%
dataframe_MG
# Out:
#               open_x    high_x     low_x   close_x   volume_x Name_x  \
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416   AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425   AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363   AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995   AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154   AAPL
# 2013-02-15   66.9785   67.1656   65.7028   65.7371   97924631   AAPL
# 2013-02-19   65.8714   66.1042   64.8356   65.7128  108854046   AAPL
# 2013-02-20   65.3842   65.3842   64.1142   64.1214  118891367   AAPL
# 2013-02-21   63.7142   64.1671   63.2599   63.7228  111596821   AAPL
# 2013-02-22   64.1785   64.5142   63.7999   64.4014   82583823   AAPL
# 2013-02-25   64.8356   65.0171   63.2242   63.2571   92899597   AAPL
# 2013-02-26   63.4028   64.5056   62.5228   64.1385  125096657   AAPL
# ...
