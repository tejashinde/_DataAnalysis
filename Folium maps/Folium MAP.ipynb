# %%
import folium
from re import findall
import random

# %%
# length = sum(1 for line in open('./data/2911204.gpx'))
with open('./data/2911204.gpx' , 'rt') as file:
    data = file.read()
# print(findall('lat="([0-9.]+)" lon="([0-9.]+)"' , file.read()))
loc_data = findall('<trkpt lat="([^"]+)" lon="([^"]+)"' , data)
#     print(file.read())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-635b09c04f96> in <module>
#       3     data = file.read()
#       4 # print(findall('lat="([0-9.]+)" lon="([0-9.]+)"' , file.read()))
# ----> 5 loc_data = float(findall('<trkpt lat="([^"]+)" lon="([^"]+)"' , data))
#       6 #     print(file.read())
#
# TypeError: float() argument must be a string or a number, not 'list'

# %%
folium.features.PolyLine(loc_data).add_to()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0392ac61273d> in <module>
# ----> 1 folium.features.PolyLine(loc_data).add_to(folium.Map(location = loc_data[random.randint(0 , len(loc_data))] , zoom_start = 15))
#
# ~/.local/lib/python3.6/site-packages/folium/vector_layers.py in __init__(self, locations, popup, tooltip, **kwargs)
#     165     def __init__(self, locations, popup=None, tooltip=None, **kwargs):
#     166         super(PolyLine, self).__init__(location=locations, popup=popup,
# --> 167                                        tooltip=tooltip)
#     168         self._name = 'PolyLine'
#     169         self.options = _parse_options(line=True, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/folium/map.py in __init__(self, location, popup, tooltip, icon)
#     250         self._name = 'Marker'
#     251         self.tooltip = tooltip
# ...

# %%
# mAp = folium.Map(location = int(loc_data[random.randint(0 , len(loc_data))]) , zoom_start = 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-500dccf752e6> in <module>
# ----> 1 mAp = folium.Map(location = int(loc_data[random.randint(0 , len(loc_data))]) , zoom_start = 15)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'tuple'

# %%
loc_data
# Out:
# [('-8.087243000', '-34.956658000'),
#  ('-8.087315000', '-34.956808000'),
#  ('-8.087376000', '-34.956945000'),
#  ('-8.087427000', '-34.957087000'),
#  ('-8.087469000', '-34.957219000'),
#  ('-8.087522000', '-34.957344000'),
#  ('-8.087550000', '-34.957433000'),
#  ('-8.087595000', '-34.957527000'),
#  ('-8.087640000', '-34.957608000'),
#  ('-8.087674000', '-34.957690000'),
#  ('-8.087702000', '-34.957770000'),
#  ('-8.087735000', '-34.957858000'),
#  ('-8.087771000', '-34.957940000'),
#  ('-8.087813000', '-34.958038000'),
#  ('-8.087851000', '-34.958120000'),
#  ('-8.087889000', '-34.958211000'),
#  ('-8.087930000', '-34.958301000'),
#  ('-8.087991000', '-34.958389000'),
#  ('-8.088016000', '-34.958479000'),
#  ('-8.088036000', '-34.958560000'),
#  ('-8.088058000', '-34.958650000'),
#  ('-8.088079000', '-34.958733000'),
#  ('-8.088086000', '-34.958828000'),
#  ('-8.088084000', '-34.958910000'),
#  ('-8.088079000', '-34.959010000'),
#  ('-8.088072000', '-34.959115000'),
# ...
